# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv("uber.csv")

# %%
data
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count'],
#       dtype='object')

# %%
data=data.drop(['Unnamed: 0'], axis=1)

# %%
data=data.drop(['key'],axis=1)

# %%
data.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
data.shape
# Out:
# (200000, 7)

# %%
data.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
data['dropoff_longitude'].fillna(value=data['dropoff_longitude'].mean(),inplace=True)
# Out:
# C:\Users\vaish\AppData\Local\Temp\ipykernel_10512\2784462317.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['dropoff_longitude'].fillna(value=data['dropoff_longitude'].mean(),inplace=True)

# %%
data['dropoff_latitude'].fillna(value=data['dropoff_latitude'].median(),inplace= True)
# Out:
# C:\Users\vaish\AppData\Local\Temp\ipykernel_10512\1404873724.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['dropoff_latitude'].fillna(value=data['dropoff_latitude'].median(),inplace= True)

# %%
data.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
data.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
data.pickup_datetime=pd.to_datetime(data.pickup_datetime,errors='coerce')

# %%
data.dtypes
# Out:
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                float64
# dropoff_latitude                 float64
# passenger_count                    int64
# dtype: object

# %%
data['year']=data['pickup_datetime'].dt.year
data['month']=data['pickup_datetime'].dt.month
data['hour']= data['pickup_datetime'].dt.hour
data['dayofweek']=data['pickup_datetime'].dt.dayofweek
data['day']=data['pickup_datetime'].dt.day

# %%
data.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  year  month  hour  \
# 0         -73.999512         40.723217                1  2015      5    19
# 1         -73.994710         40.750325                1  2009      7    20
# 2         -73.962565         40.772647                1  2009      8    21
# 3         -73.965316         40.803349                3  2009      6     8
# 4         -73.973082         40.761247                5  2014      8    17
#
#    dayofweek  day
# 0          3    7
# 1          4   17
# ...

# %%
data =data.drop(['pickup_datetime'],axis=1)

# %%
data.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  year  month  hour  dayofweek  day
# 0         40.723217                1  2015      5    19          3    7
# 1         40.750325                1  2009      7    20          4   17
# 2         40.772647                1  2009      8    21          0   24
# 3         40.803349                3  2009      6     8          4   26
# 4         40.761247                5  2014      8    17          3   28

# %%
data.plot(kind="box",subplots=True, layout=(7,2),figsize=(15,20))
# Out:
# fare_amount             Axes(0.125,0.786098;0.352273x0.0939024)
# pickup_longitude     Axes(0.547727,0.786098;0.352273x0.0939024)
# pickup_latitude         Axes(0.125,0.673415;0.352273x0.0939024)
# dropoff_longitude    Axes(0.547727,0.673415;0.352273x0.0939024)
# dropoff_latitude        Axes(0.125,0.560732;0.352273x0.0939024)
# passenger_count      Axes(0.547727,0.560732;0.352273x0.0939024)
# year                    Axes(0.125,0.448049;0.352273x0.0939024)
# month                Axes(0.547727,0.448049;0.352273x0.0939024)
# hour                    Axes(0.125,0.335366;0.352273x0.0939024)
# dayofweek            Axes(0.547727,0.335366;0.352273x0.0939024)
# day                     Axes(0.125,0.222683;0.352273x0.0939024)
# dtype: object

# %%
def remove_outlier(data1,col):
    Q1=data1[col].quartile(0.25)
    Q3=data1[col].quartile(0.75)
    IQR=Q3-Q1
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR
    
    data1[col]=np.where(data1[col]<lower_bound,lower_bound.data1[col])
    data1[col]=np.where(data1[col]<upper_bound,upper_bound.data1[col])
    return data1

# %%
def treat_outliers(data):

    col_list = data.select_dtypes(include=[np.number]).columns
    for col in col_list:
        data = remove_outliers(data, col)
    return data

# %%
data1=treat_outliers(data)

# %%
data.plot(kind="box",subplots=True, layout=(7,2),figsize=(15,20))
# Out:
# fare_amount             Axes(0.125,0.786098;0.352273x0.0939024)
# pickup_longitude     Axes(0.547727,0.786098;0.352273x0.0939024)
# pickup_latitude         Axes(0.125,0.673415;0.352273x0.0939024)
# dropoff_longitude    Axes(0.547727,0.673415;0.352273x0.0939024)
# dropoff_latitude        Axes(0.125,0.560732;0.352273x0.0939024)
# passenger_count      Axes(0.547727,0.560732;0.352273x0.0939024)
# year                    Axes(0.125,0.448049;0.352273x0.0939024)
# month                Axes(0.547727,0.448049;0.352273x0.0939024)
# hour                    Axes(0.125,0.335366;0.352273x0.0939024)
# dayofweek            Axes(0.547727,0.335366;0.352273x0.0939024)
# day                     Axes(0.125,0.222683;0.352273x0.0939024)
# dtype: object

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data1.corr(),annot=True,cmap='coolwarm')
plt.title('correlation matrix')
plt.show()

# %%
x=data.drop('fare_amount',axis=1)
y=data['fare_amount']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(x_test)

# %%
y_pred
# Out:
# array([11.01888719, 17.29923715,  9.59715555, ...,  9.87150062,
#         9.08990171, 10.26102439])

# %%
randomforest=RandomForestRegressor(n_estimators=50,random_state=42)

# %%
randomforest.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=42)

# %%
y_pred2=randomforest.predict(x_test)

# %%
y_pred2
# Out:
# array([ 6.04 , 13.658,  7.148, ...,  5.28 ,  6.614,  8.39 ])

# %%
r1=r2_score(y_test,y_pred)

# %%
r1
# Out:
# 0.11310450007374151

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
print(mse)
# Out:
# 26.386687558355497

# %%
print(mse)
# Out:
# 26.386687558355497

# %%
rmse=np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(5.136797402891757)

# %%
r2=r2_score(y_test,y_pred2)

# %%
r2
# Out:
# 0.7904873930044729

# %%
mse2=mean_squared_error(y_test,y_pred2)

# %%
mse2
# Out:
# np.float64(6.233365374823931)

# %%
rmse2=np.sqrt(mse2)

# %%
rmse2
# Out:
# np.float64(2.496670858327932)
